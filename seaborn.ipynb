# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn  as sns
sns.set()

# %%
x = [10,20,30,40]
y = [0,15,10,25]

# %%
plt.plot(x,y);

# %%
sns.set_style('white')

# %%
plt.plot(x,y);

# %% [markdown]
# # Seaborn with pandas

# %%
cars = sns.load_dataset('mpg')

# %%
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars.shape
# Out:
# (398, 9)

# %%
cars.dropna(inplace = True)
cars.shape
# Out:
# (392, 9)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.relplot(x='model_year',y='mpg',col = 'origin',hue='cylinders',data=cars);

# %% [markdown]
# # KDE Kernel density estimation

# %% [markdown]
# ### Seaborn univairiate kde plot

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.kdeplot(cars.horsepower);

# %%
sns.kdeplot(cars.horsepower,fill=True);

# %%
sns.kdeplot(cars.horsepower,bw_adjust=1);

# %%
from scipy.stats import norm

# %%
sns.kdeplot(cars.horsepower,cumulative=True);

# %% [markdown]
# # Bivariate data

# %%
sns.kdeplot(data=cars,x='horsepower',y='mpg');

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.kdeplot(data=cars,x='horsepower',y='mpg',n_levels=20);

# %%
sns.kdeplot(data=cars,x='horsepower',y='mpg',fill=True,thresh=False);

# %%
sns.kdeplot(data=cars,x='horsepower',y='mpg',fill=True,cbar=True);

# %% [markdown]
# # Seaborn Distplot

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.set_style('white')

# %%
sns.distplot(cars.weight);
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6928\1016146276.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight);

# %%
sns.displot(cars.weight,kde=True);

# %%
sns.distplot(cars.weight,hist=False,rug=True);
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6928\1112166184.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight,hist=False,rug=True);

# %%
sns.distplot(cars.weight,bins=20);
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6928\525983342.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight,bins=20);

# %%
sns.distplot(cars.weight, bins=[1500,2000,2500,3500,5200]);
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6928\3174910665.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight, bins=[1500,2000,2500,3500,5200]);

# %%
sns.distplot(cars.weight,fit=norm);
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6928\330261329.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight,fit=norm);

# %%
from scipy.stats import skewnorm
sns.distplot(cars.weight,fit=skewnorm,kde=False)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6928\922127475.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight,fit=skewnorm,kde=False)
# <Axes: xlabel='weight'>

# %%
sns.distplot(cars.weight,hist_kws={'alpha':1});
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6928\2034411891.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight,hist_kws={'alpha':1});

# %%
sns.distplot(cars.weight,hist_kws={'alpha':1,'histtype':'step'});
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6928\3307106955.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight,hist_kws={'alpha':1,'histtype':'step'});

# %%
sns.distplot(cars.weight,kde_kws={'lw':5});
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6928\3653487730.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(cars.weight,kde_kws={'lw':5});

# %% [markdown]
# # boxplot

# %%
cars.head(
)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.set_style('whitegrid')

# %%
cars.cylinders.value_counts()
# Out:
# cylinders
# 4    199
# 8    103
# 6     83
# 3      4
# 5      3
# Name: count, dtype: int64

# %% [markdown]
# #### Filter down to cars with only even number of culinders

# %%
cars = cars[cars.cylinders.isin([4,6,8])]

# %%
sns.boxplot(cars.mpg);

# %%
cars.mpg.describe()
# Out:
# count    385.000000
# mean      23.445455
# std        7.836911
# min        9.000000
# 25%       17.000000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
sns.boxplot(x=cars.origin,y=cars.mpg);

# %%
sns.boxplot(x='origin',y='mpg',data=cars);

# %% [markdown]
# # Hue

# %% [markdown]
# ## By cylinders

# %%
sns.boxplot(x='origin',y='mpg', hue= 'cylinders',data=cars);

# %% [markdown]
# # by model year

# %%
cars.model_year.describe()
# Out:
# count    385.000000
# mean      75.961039
# std        3.692058
# min       70.000000
# 25%       73.000000
# 50%       76.000000
# 75%       79.000000
# max       82.000000
# Name: model_year, dtype: float64

# %%
cars['newer_model'] =cars.model_year > 76

# %%
sns.boxplot(x='origin',y='mpg', hue= 'newer_model',data=cars);

# %% [markdown]
# # Styling Options

# %%
sns.boxplot(y='origin',x='mpg',data=cars);

# %%
sns.boxplot(x='origin',y='mpg', order=['japan','europe','usa'],data=cars);

# %%
sns.boxplot(x='origin',y='mpg', hue= 'newer_model',data=cars,hue_order=[True,False]);

# %% [markdown]
# # colour

# %%
sns.boxplot(x='origin',y='mpg',data=cars,color='g',width=0.5,linewidth=3.5);

# %%
sns.boxplot(x='origin',y='mpg',data=cars,whis=2);

# %% [markdown]
# # Fliersize

# %%
sns.boxplot(x='origin',y='mpg',data=cars,whis=2,fliersize=10);

# %%
sns.boxplot(x='mpg',y='origin',data = cars,showcaps=False);
